# %%
## Task 1: Data Loading (Python)

# 1. Read the csv file and load it into a pandas dataframe.
# 2. Display the first five rows of your dataframe.
# 3. Display the data types of the columns.

# %%
# 1. Read the csv file and load it into a pandas dataframe.

# Importing the libraries
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# Import the data 
data = pd.read_csv('/Users/viedamayanti/Desktop/IBM-FinalProject/Airbnb_Open_Data.csv', low_memory=False)

# %%
# 2. Display the first five rows of your dataframe.
data.head()
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long        country  ... service fee minimum nights  \
# ...

# %%
# 3. Display the data types of the columns.
data.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='object')

# %%
# NOTES
# ID: A unique identifier assigned to each Airbnb listing.
# Name: The title or name given to the Airbnb property by the host.
# Host ID: Unique identifier for the host of the property.
# Host Identity Verified: Indicates if the host's identity has been verified by Airbnb.
# Host Name: Name of the host of the property.
# Neighbourhood Group: The grouping of neighborhoods within a larger area (could be a city or district).
# Neighbourhood: Specific neighborhood where the property is located.
# Latitude and Longitude: Geographic coordinates of the property's location.
# Country and Country Code: Country where the property is situated, along with its code.
# Instant Bookable: Whether the property can be instantly booked without the host's approval.
# Cancellation Policy: The policy regarding cancellations made by guests.
# Room Type: Type of accommodation offered (e.g., entire home, private room, shared room).
# Construction Year: The year in which the property was constructed.
# Price: The price per night for renting the property.
# Service Fee: Additional fees charged for services.
# Minimum Nights: The minimum number of nights a guest can book.
# Number of Reviews: Total number of reviews received for the property.
# Last Review: Date of the last review given by a guest.
# Reviews per Month: Average number of reviews received per month.
# Review Rate Number: A metric related to the rate of reviews.
# Calculated Host Listings Count: The number of properties listed by the host.
# Availability 365: Number of days the property is available for booking in a year.
# House Rules: Rules and regulations set by the host for guests staying at the property.
# License: License details or registration information for the property.

# %%
## Task 2a: Data Cleaning 
# Exploring how many numbers of rows and columns on the data 
data.shape
# Out:
# (102599, 26)

# %%
# Display the data types of the columns 
data.dtypes
# Out:
# id                                  int64
# NAME                               object
# host id                             int64
# host_identity_verified             object
# host name                          object
# neighbourhood group                object
# neighbourhood                      object
# lat                               float64
# long                              float64
# country                            object
# country code                       object
# instant_bookable                   object
# cancellation_policy                object
# room type                          object
# Construction year                 float64
# price                              object
# service fee                        object
# minimum nights                    float64
# number of reviews                 float64
# last review                        object
# reviews per month                 float64
# review rate number                float64
# ...

# %%
# Check if the null value of the data (descending order)
data.isnull().sum().sort_values()
# Out:
# id                                     0
# room type                              0
# host id                                0
# long                                   8
# lat                                    8
# neighbourhood                         16
# neighbourhood group                   29
# cancellation_policy                   76
# instant_bookable                     105
# country code                         131
# number of reviews                    183
# Construction year                    214
# price                                247
# NAME                                 250
# service fee                          273
# host_identity_verified               289
# calculated host listings count       319
# review rate number                   326
# host name                            406
# minimum nights                       409
# availability 365                     448
# country                              532
# reviews per month                  15879
# ...

# %%
# 1. Drop some of the unwanted columns. These include `host id`, `id`, `country`, `country code`, `license` from the dataset.
data = data.drop(columns=['host id', 'id', 'country', 'country code', 'license'],axis=1)

# 2. State the reason for not including these columns for your Data Analytics.
# Host ID and ID are not particularly relevant for analysis, which is why I opted to drop this data. 
# Additionally, as the locations are solely within the US, the country code and country columns were removed. 
# The 'License' column contained null values, prompting its removal from the dataset.

# %%
data.columns
# Out:
# Index(['NAME', 'host_identity_verified', 'host name', 'neighbourhood group',
#        'neighbourhood', 'lat', 'long', 'instant_bookable',
#        'cancellation_policy', 'room type', 'Construction year', 'price',
#        'service fee', 'minimum nights', 'number of reviews', 'last review',
#        'reviews per month', 'review rate number',
#        'calculated host listings count', 'availability 365', 'house_rules'],
#       dtype='object')

# %%
# Check if data column change correctly
data.head(3)
# Out:
#                                   NAME host_identity_verified host name  \
# 0   Clean & quiet apt home by the park            unconfirmed  Madaline
# 1                Skylit Midtown Castle               verified     Jenna
# 2  THE VILLAGE OF HARLEM....NEW YORK !                    NaN     Elise
#
#   neighbourhood group neighbourhood       lat      long instant_bookable  \
# 0            Brooklyn    Kensington  40.64749 -73.97237            False
# 1           Manhattan       Midtown  40.75362 -73.98377            False
# 2           Manhattan        Harlem  40.80902 -73.94190             True
#
#   cancellation_policy        room type  ...  price service fee minimum nights  \
# 0              strict     Private room  ...  $966        $193            10.0
# 1            moderate  Entire home/apt  ...  $142         $28            30.0
# 2            flexible     Private room  ...  $620        $124             3.0
#
# ...

# %%
#Check the duplicate data 
data.shape
# Out:
# (102599, 21)

# %%
data.duplicated().sum()
# Out:
# 3436

# %%
data.drop_duplicates(inplace=True)

# %%
# Check the data again 
data.duplicated().sum()
# Out:
# 0

# %%
# Looping all the value and fill up the null value
for col in data.columns:
    if data[col].dtype == 'object':
        print(col)
        data[col].fillna(value=data[col].mode()[0], inplace=True)
    else:
        data[col].fillna(value=data[col].median(), inplace=True)
# Out:
# NAME
# host_identity_verified
# host name
# neighbourhood group
# neighbourhood
# instant_bookable
# cancellation_policy
# room type
# price
# service fee
# last review
# house_rules

# %%
# Check if the null value of the data again with descending order
data.isnull().sum().sort_values()
# Out:
# NAME                              0
# calculated host listings count    0
# review rate number                0
# reviews per month                 0
# last review                       0
# number of reviews                 0
# minimum nights                    0
# service fee                       0
# price                             0
# availability 365                  0
# Construction year                 0
# cancellation_policy               0
# instant_bookable                  0
# long                              0
# lat                               0
# neighbourhood                     0
# neighbourhood group               0
# host name                         0
# host_identity_verified            0
# room type                         0
# house_rules                       0
# dtype: int64

# %%
data.shape
# Out:
# (99163, 21)

# %%
data.columns
# Out:
# Index(['NAME', 'host_identity_verified', 'host name', 'neighbourhood group',
#        'neighbourhood', 'lat', 'long', 'instant_bookable',
#        'cancellation_policy', 'room type', 'Construction year', 'price',
#        'service fee', 'minimum nights', 'number of reviews', 'last review',
#        'reviews per month', 'review rate number',
#        'calculated host listings count', 'availability 365', 'house_rules'],
#       dtype='object')

# %%
# Rename the column
data.rename(columns={'availability 365':'days_booked'}, inplace=True)

# %%
# Convert all columns to lowercase and replace the space with underscore
data.columns
# Out:
# Index(['NAME', 'host_identity_verified', 'host name', 'neighbourhood group',
#        'neighbourhood', 'lat', 'long', 'instant_bookable',
#        'cancellation_policy', 'room type', 'Construction year', 'price',
#        'service fee', 'minimum nights', 'number of reviews', 'last review',
#        'reviews per month', 'review rate number',
#        'calculated host listings count', 'days_booked', 'house_rules'],
#       dtype='object')

# %%
data.columns =[col.lower().replace(' ','_') for col in data.columns]
data.columns
# Out:
# Index(['name', 'host_identity_verified', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'lat', 'long', 'instant_bookable',
#        'cancellation_policy', 'room_type', 'construction_year', 'price',
#        'service_fee', 'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'review_rate_number',
#        'calculated_host_listings_count', 'days_booked', 'house_rules'],
#       dtype='object')

# %%
# Check the column name 
data.head(3)
# Out:
#                                   name host_identity_verified host_name  \
# 0   Clean & quiet apt home by the park            unconfirmed  Madaline
# 1                Skylit Midtown Castle               verified     Jenna
# 2  THE VILLAGE OF HARLEM....NEW YORK !            unconfirmed     Elise
#
#   neighbourhood_group neighbourhood       lat      long  instant_bookable  \
# 0            Brooklyn    Kensington  40.64749 -73.97237             False
# 1           Manhattan       Midtown  40.75362 -73.98377             False
# 2           Manhattan        Harlem  40.80902 -73.94190              True
#
#   cancellation_policy        room_type  ...  price service_fee minimum_nights  \
# 0              strict     Private room  ...  $966        $193            10.0
# 1            moderate  Entire home/apt  ...  $142         $28            30.0
# 2            flexible     Private room  ...  $620        $124             3.0
#
# ...

# %%
# Remove the dollar sign 
data[['price','service_fee']].head()
# Out:
#    price service_fee
# 0  $966        $193
# 1  $142         $28
# 2  $620        $124
# 3  $368         $74
# 4  $204         $41

# %%
def remove_dollar_comma_sign(value):
    if pd.isna(value):
        return np.Nan
    else:
        return value.replace("$","").replace(",","")

# %%
data['price'] = data['price'].apply(lambda x:remove_dollar_comma_sign(x))
data['service_fee'] = data['service_fee'].apply(lambda x:remove_dollar_comma_sign(x))

# %%
data[['price','service_fee']].head()
# Out:
#   price service_fee
# 0  966         193
# 1  142          28
# 2  620         124
# 3  368          74
# 4  204          41

# %%
# Data manipulation
# Standardizing capitalization using str.title()
data['neighbourhood_group'] = data['neighbourhood_group'].str.title()

# Manually replacing misspelled words or variations
corrections = {
    'Broklyn': 'Brooklyn',
    'brookln': 'Brooklyn',
    'manhatan': 'Manhattan',
    'manhattan': 'Manhattan',
    'Brookln': 'Brooklyn',
    'Manhatan': 'Manhattan',
}

for incorrect, correct in corrections.items():
    data['neighbourhood_group'] = data['neighbourhood_group'].str.replace(incorrect, correct)

# %%
data['neighbourhood_group']
# Out:
# 0          Brooklyn
# 1         Manhattan
# 2         Manhattan
# 3          Brooklyn
# 4         Manhattan
#             ...
# 102053     Brooklyn
# 102054     Brooklyn
# 102055     Brooklyn
# 102056    Manhattan
# 102057    Manhattan
# Name: neighbourhood_group, Length: 99163, dtype: object

# %%
# Exploratory data analysis
# List the count of various room types avaliable with Airbnb
data['room_type'].unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room', 'Hotel room'],
#       dtype=object)

# %%
room_type_counts = data['room_type'].value_counts()
room_type_counts
# Out:
# room_type
# Entire home/apt    52003
# Private room       44895
# Shared room         2150
# Hotel room           115
# Name: count, dtype: int64

# %%
# Which room type has to more strict cancellation policy
data['cancellation_policy'].unique()
# Out:
# array(['strict', 'moderate', 'flexible'], dtype=object)

# %%
data_cancelation_group =  data[data['cancellation_policy'] == 'strict']
data_cancelation_group.shape
# Out:
# (32930, 21)

# %%
data_cancelation_group.head(2)
# Out:
#                                  name host_identity_verified host_name  \
# 0  Clean & quiet apt home by the park            unconfirmed  Madaline
# 8     Large Furnished Room Near B'way               verified    Evelyn
#
#   neighbourhood_group   neighbourhood       lat      long  instant_bookable  \
# 0            Brooklyn      Kensington  40.64749 -73.97237             False
# 8           Manhattan  Hell's Kitchen  40.76489 -73.98493              True
#
#   cancellation_policy     room_type  ...  price service_fee minimum_nights  \
# 0              strict  Private room  ...   966         193            10.0
# 8              strict  Private room  ...  1018         204             2.0
#
#    number_of_reviews  last_review reviews_per_month  review_rate_number  \
# 0                9.0   10/19/2021              0.21                 4.0
# 8              430.0    6/24/2019              3.47                 3.0
#
#    calculated_host_listings_count  days_booked  \
# ...

# %%
data_cancelation_group['room_type'].value_counts()
# Out:
# room_type
# Entire home/apt    17241
# Private room       14937
# Shared room          718
# Hotel room            34
# Name: count, dtype: int64

# %%
data[['price','service_fee']].dtypes
# Out:
# price          object
# service_fee    object
# dtype: object

# %%
# Convert the 'price','service_fee' to integer
data['price'] = data['price'].astype(int)
data['service_fee'] = data['service_fee'].astype(int)

# %%
# List the prices by neighborhood group and also mention which is the most expensive neighborhood group for rentals
grp_avg = data['price'].groupby(data['neighbourhood_group']).mean().sort_values(ascending=False)
grp_avg
# Out:
# neighbourhood_group
# Queens           628.623754
# Bronx            625.488914
# Brooklyn         625.458794
# Staten Island    625.060870
# Manhattan        621.612782
# Name: price, dtype: float64

# %%
grp_avg_min = data['price'].groupby(data['neighbourhood_group']).min().sort_values()
grp_avg_min
# Out:
# neighbourhood_group
# Bronx            50
# Brooklyn         50
# Manhattan        50
# Queens           50
# Staten Island    50
# Name: price, dtype: int64

# %%
# Data Visualization
# List the count of various room types avaliable with Airnb
# Creating a bar plot to visualize the count of each room type
room_type_counts = data['room_type'].value_counts()
print(room_type_counts)
# Creating a bar plot using Seaborn
sns.barplot(x=room_type_counts.index, y=room_type_counts.values)
# Out:
# room_type
# Entire home/apt    52003
# Private room       44895
# Shared room         2150
# Hotel room           115
# Name: count, dtype: int64
# <Axes: xlabel='room_type'>

# %%
# Which room type adheres to more strict cancellation policy
room_type_strict = data_cancelation_group['room_type'].value_counts()
print(room_type_strict)
# Out:
# room_type
# Entire home/apt    17241
# Private room       14937
# Shared room          718
# Hotel room            34
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 6))
plt.bar(room_type_strict.index, room_type_strict.values, color='skyblue')
plt.xlabel('Room Type')
plt.ylabel('Count')
plt.title('Count of Room Types with Strict Cancellation Policy')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# List the prices by neighborhood group and also mention which is the most expensive neighborhood group for rentals
grp_avg
# Out:
# neighbourhood_group
# Queens           628.623754
# Bronx            625.488914
# Brooklyn         625.458794
# Staten Island    625.060870
# Manhattan        621.612782
# Name: price, dtype: float64

# %%
plt.figure(figsize=(10, 6))
grp_avg.plot(kind='bar', color='blue')
plt.title('Average Prices by Neighborhood Group')
plt.xlabel('Neighborhood Group')
plt.ylabel('Average Price')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# List the top 10 neighborhoods in the increasing order of their price with the help of a horizontal bar graph. Which is the cheapest neighborhood.
grp_avg2 = data['price'].groupby(data['neighbourhood']).sum().sort_values(ascending=False)
grp_avg2
# Out:
# neighbourhood
# Bedford-Stuyvesant            4796529
# Williamsburg                  4663518
# Harlem                        3318330
# Bushwick                      3038762
# Hell's Kitchen                2394881
#                                ...
# Glen Oaks                        1101
# Chelsea, Staten Island           1042
# Bay Terrace, Staten Island        918
# Rossville                         655
# Lighthouse Hill                   323
# Name: price, Length: 224, dtype: int64

# %%
top_10_expensive = grp_avg2.head(10)
top_10_expensive
# Out:
# neighbourhood
# Bedford-Stuyvesant    4796529
# Williamsburg          4663518
# Harlem                3318330
# Bushwick              3038762
# Hell's Kitchen        2394881
# Upper West Side       2306602
# Upper East Side       2178236
# East Village          2081467
# Midtown               1986947
# Crown Heights         1943244
# Name: price, dtype: int64

# %%
plt.figure(figsize=(8, 6))
top_10_expensive.plot(kind='barh', color='skyblue')
plt.title('Average Prices by Neighborhood')
plt.xlabel('Neighborhood')
plt.ylabel('Average Price')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
data.columns
# Out:
# Index(['name', 'host_identity_verified', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'lat', 'long', 'instant_bookable',
#        'cancellation_policy', 'room_type', 'construction_year', 'price',
#        'service_fee', 'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'review_rate_number',
#        'calculated_host_listings_count', 'days_booked', 'house_rules'],
#       dtype='object')

# %%
# List the neighborhoods which offer short term rentals within 10 days. Illustrate with a bar graph
sort_term_listing = data[data['minimum_nights'] < 10]
data1 = sort_term_listing['neighbourhood_group'].value_counts()
data1
# Out:
# neighbourhood_group
# Brooklyn         34351
# Manhattan        32799
# Queens           10973
# Bronx             2368
# Staten Island      829
# Name: count, dtype: int64

# %%
# Filter the data for listings with a maximum stay duration of 10 days and positive minimum nights
short_term_listings = data[(data['minimum_nights'] < 10) & (data['minimum_nights'] >= 0)]
short_term_listings
# Plotting the count of listings by 'minimum_nights' (filtered under 10 and positive) and 'neighbourhood_group'
plt.figure(figsize=(12, 8))
sns.countplot(x='minimum_nights', hue='neighbourhood_group', data=short_term_listings)
plt.title('Count of Short-Term Rentals within 10 Days by Minimum Nights and Neighborhood Group')
plt.xlabel('Minimum Nights (Under 10)')
plt.ylabel('Count of Listings')
plt.legend(title='Neighbourhood Group')
plt.tight_layout()
plt.show()

# %%
data_filter_min = data[data['minimum_nights']< 10]
data_filter_min['neighbourhood_group'].value_counts()

sns.barplot(x='minimum_nights',y='neighbourhood_group',data=data_filter_min, orient='h')
# Out:
# <Axes: xlabel='minimum_nights', ylabel='neighbourhood_group'>

# %%
data1 = data.groupby(['room_type']).agg(mean_price=('price','mean'))
data1 = data1.reset_index()
data1.head()
# Out:
#          room_type  mean_price
# 0  Entire home/apt  624.191662
# 1       Hotel room  666.391304
# 2     Private room  623.829469
# 3      Shared room  630.852558

# %%
# List the prices with respect to room type using a bar graph and also state your inferences.
plt.figure(figsize=(8, 6))
sns.barplot(x='room_type', y='price', data=data)
plt.title('Average Prices by Room Type')
plt.xlabel('Room Type')
plt.ylabel('Average Price')
plt.tight_layout()
plt.show()

# %%
# Create a pie chart that shows  distribution of booked days for each neighborhood group .Which neighborhood has the highest booking percentage.
data2 = data['days_booked'].groupby(data['neighbourhood_group']).mean().sort_values().reset_index()
data2
# Out:
#   neighbourhood_group  days_booked
# 0            Brooklyn   130.755163
# 1           Manhattan   142.689471
# 2              Queens   162.422741
# 3               Bronx   179.009939
# 4       Staten Island   195.992391

# %%
pallete_color = sns.color_palette('bright')
plt.pie(data2['days_booked'], labels=data2['neighbourhood_group'],colors=pallete_color, autopct='%.0f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x12bad4990>,
# ...
#  [Text(0.9618438803753367, 0.5337193548902972, 'Brooklyn'),
#   Text(0.005263512349763153, 1.0999874069450721, 'Manhattan'),
#   Text(-1.015942662512712, 0.4217351141256584, 'Queens'),
#   Text(-0.6581819788580512, -0.8813605860863646, 'Bronx'),
#   Text(0.7978173177448411, -0.7572895928945725, 'Staten Island')],
#  [Text(0.5246421165683655, 0.29111964812198027, '16%'),
#   Text(0.002871006736234447, 0.5999931310609484, '18%'),
#   Text(-0.5541505431887519, 0.23003733497763182, '20%'),
#   Text(-0.3590083521043915, -0.48074213786528974, '22%'),
#   Text(0.4351730824062769, -0.41306705066976684, '24%')])

# %%
# Does service price and room price have an impact on each other. Illustrate this relationship with a scatter plot and state your inferences

# Plotting a scatter plot between service price and room price
plt.figure(figsize=(12, 10))
plt.title('Relationship between Service Fee and Room Price')
sns.scatterplot(x=data['room_type'],y=data['service_fee'],s=10)
plt.grid(True)
plt.show()

# %%
data.columns
# Out:
# Index(['name', 'host_identity_verified', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'lat', 'long', 'instant_bookable',
#        'cancellation_policy', 'room_type', 'construction_year', 'price',
#        'service_fee', 'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'review_rate_number',
#        'calculated_host_listings_count', 'days_booked', 'house_rules'],
#       dtype='object')

# %%
data[['price','service_fee','room_type']]
# Out:
#         price  service_fee        room_type
# 0         966          193     Private room
# 1         142           28  Entire home/apt
# 2         620          124     Private room
# 3         368           74  Entire home/apt
# 4         204           41  Entire home/apt
# ...       ...          ...              ...
# 102053    696          216     Private room
# 102054    909          216     Private room
# 102055    387          216  Entire home/apt
# 102056    848          216     Private room
# 102057   1128          216  Entire home/apt
#
# [99163 rows x 3 columns]

# %%
# Assuming 'data' contains 'service_fee' and 'price' columns
correlation = data['service_fee'].corr(data['price'])

print(f"Correlation coefficient between service price and room price: {correlation}")
# Out:
# Correlation coefficient between service price and room price: 0.9933065168978503

# %%
# A correlation coefficient close to 1 suggests that there's a high tendency for the two variables ('service_fee' and 'price') to move together in a linear manner.
# Specifically, a value of 0.99 indicates that as one variable (service fee) increases, the other variable (room price) tends to increase as well, and vice versa, in a nearly perfect linear fashion.

# %%
# Assuming 'data' contains columns: 'service_fee', 'room_type', and 'price'

# Create a scatter plot using Seaborn
plt.figure(figsize=(10, 5))
sns.scatterplot(x='price', y='service_fee', hue='room_type', data=data)
plt.title('Relationship between Service Fee, Room Type, and Price')
plt.xlabel('Price')
plt.ylabel('service_fee')
plt.legend(title='Room Type', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
data.columns
# Out:
# Index(['name', 'host_identity_verified', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'lat', 'long', 'instant_bookable',
#        'cancellation_policy', 'room_type', 'construction_year', 'price',
#        'service_fee', 'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'review_rate_number',
#        'calculated_host_listings_count', 'days_booked', 'house_rules'],
#       dtype='object')

# %%
# Using a line graph show in which year the maximum construction of rooms took place.
plt.figure(figsize=(10,5))
data['construction_year_counts'] = data['construction_year'].value_counts()

# %%
sns.lineplot(x='construction_year',y='construction_year_counts', data = data)
# Out:
# <Axes: xlabel='construction_year', ylabel='construction_year_counts'>

# %%
# Create a scatter plot for 'review_rate_number' vs 'price'
sns.boxplot(x='review_rate_number', y='price', data=data)
# Out:
# <Axes: xlabel='review_rate_number', ylabel='price'>

# %%
# Effect of host identity verified on price
sns.boxplot(x='host_identity_verified', y='price', data=data)
# Out:
# <Axes: xlabel='host_identity_verified', ylabel='price'>

# %%
# Converting to csv file
data.to_csv('AirBnBediteddata.csv', index=False)
